# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import tweepy
import csv #Import csv
import datetime
auth = tweepy.auth.OAuthHandler('4DkUB9PrsJMV42Egna5JTD5Mu', 'YpB18rptFNKl4igUifoo8s3gODOPzDKwwbzKeWUyz68cGGFmtW')
auth.set_access_token('1184847924653637635-RVSOIe7rDSzFyuARGUn9oWFUuuv7OJ', 'MJGyvOsGn3PCN3OqTgC2pgxu4SObpkbxQlwWZgRXxgvgB')

api = tweepy.API(auth, wait_on_rate_limit=True)

df = pd.DataFrame(columns=['username', 'description', 'location', 'following', 
                               'followers', 'totaltweets', 'retweetcount', 'text','hashtext']) 
# Open/create a file to append data to
csvFile = open('/content/drive/MyDrive/Colab Notebooks/result.csv', 'a')
db = pd.DataFrame(columns=['username', 'description', 'location', 'following', 
                               'followers', 'totaltweets', 'retweetcount', 'text', 'hashtext']) 
      

#Use csv writer
csvWriter = csv.writer(csvFile)

tweets = api.search(q="datascience",since="2020-12-25", lang='en', exclude='retweets', count=1000 ,tweet_mode='extended')


for tweet in tweets:
    # Write a row to the CSV file
    username = tweet.user.name 
    description = tweet.user.description 
    location = tweet.user.location 
    following = tweet.user.friends_count 
    followers = tweet.user.followers_count 
    totaltweets = tweet.user.statuses_count 
    retweetcount = tweet.retweet_count 
    hashtags = tweet.entities['hashtags'] 
          
    try: 
            text = tweet.retweeted_status.full_text 
    except AttributeError: 
            text = tweet.full_text 
    hashtext = list() 
    for j in range(0, len(hashtags)): 
            hashtext.append(hashtags[j]['text'])
    csvWriter.writerow([username, description, location, following, followers, totaltweets, retweetcount, text, hashtext])
    data = (username, description, location, following, followers, totaltweets, retweetcount, text, hashtext)
    db.loc[len(db)]=data
    print(data)
csvFile.close()
# Out:
# ('We Count', 'We Count is a community-driven project to address the inherent bias against small minorities and outliers in artificial intelligence and data analytics.', 'Toronto, ON ', 652, 175, 170, 0, 'We Count is addressing bias and developing new #machinelearning strategies that recognize and serve people with disabilities. Find out how in this video: https://t.co/CFdeOBMGaY. #dataecosystem #datascience #fairAI', ['machinelearning', 'dataecosystem', 'datascience', 'fairAI'])
# ('Cresco International', '#BusinessAnalytics Consulting,  Software, Support, Cloud, & Training provider || #IBM #Analytics Partner || Analytics + Performance = Growth || 844.6.CRESCO', 'Dallas, TX', 564, 262, 1297, 0, 'Take the assessment at https://t.co/yTfn6DULFx then we can provide the next steps!\n#Data #Security #Datascience https://t.co/L9g7L3rxjO', ['Data', 'Security', 'Datascience'])
# ...

# %%
col_Names=['username', 'description', 'location', 'following', 
                               'followers', 'totaltweets', 'retweetcount', 'text','hashtext']
df= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/result.csv',names=col_Names)

# %%
df
# Out:
#                username  ...                                           hashtext
# 0          Data science  ...                              ['datascience', 'ad']
# 1              claudîus  ...             ['rbloggers', 'rstats', 'datascience']
# 2      99 coupon course  ...  ['MachineLearning', 'Udemy', '100daysofcode', ...
# 3           La Forge AI  ...  ['MachineLearning', 'DataScience', 'Python', '...
# 4     Pastor Paul Stead  ...  ['Airdrop', '100DaysOfCode', 'DevOps', 'blog',...
# ..                  ...  ...                                                ...
# 661  💎𝞛𝙰Ņ๐н𝙰ℝ ⲥн๐ⲱƊ𝙰ℝÝ💎  ...  ['AR', 'Analytics', 'AI', 'BigData', 'Rstats',...
# 662      Amisi Gbialema  ...  ['keeplearning', 'technology', 'AI', 'BigTech'...
# 663     Ronald van Loon  ...  ['Robot', 'Cloud', 'MI', 'Digital', 'DataScien...
# 664  💎𝞛𝙰Ņ๐н𝙰ℝ ⲥн๐ⲱƊ𝙰ℝÝ💎  ...  ['MachineLearning', '100DaysOfCode', 'DEVCommu...
# 665  💎𝞛𝙰Ņ๐н𝙰ℝ ⲥн๐ⲱƊ𝙰ℝÝ💎  ...  ['MachineLearning', 'DataScience', 'Python', '...
#
# ...
